# %% [markdown]
# ## Assignment 2: Data Structures - List, Tuple, Set, and Dictionary

# %% [markdown]
# ### 1. Working with Lists:

# %% [markdown]
# #### 1) Create a list of integers and:a) Append a new number. b)Insert a number at a specific index.c) Remove duplicates and print the final list.

# %%
list = [1,2,3,3,6]

# %%
list.append(4)

# %%
list
# Out:
# [1, 2, 3, 3, 6, 4]

# %%
list.insert(1,0)

# %%
list
# Out:
# [1, 0, 2, 3, 3, 6, 4, 0]

# %%
list.remove(3)

# %%
list
# Out:
# [1, 0, 2, 3, 6, 4, 0]

# %%
list.remove(0)

# %%
list
# Out:
# [1, 2, 3, 6, 4, 0]

# %% [markdown]
# #### 2. Tuple Manipulation:

# %% [markdown]
# ##### Define a tuple of 5 colors.

# %%
colors = ("red", "blue", "green", "yellow", "black")

# %%
print(colors)
# Out:
# ('red', 'blue', 'green', 'yellow', 'black')

# %% [markdown]
# ##### 2) Try to add a new color to the tuple (observe and explain why it fails).

# %%
colors = ("red", "blue", "green", "yellow", "black")

# %%
colors(2)= "violet"
# Out:
#   Cell In[18], line 1
#     colors(2)= "violet"
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ### A tuple is immutable, which means its values cannot be changed after it is created. Therefore,we cannot add, remove, or modify individual items in a tuple.

# %% [markdown]
# #### 3) Convert the tuple to a list, add the color, and convert it back to a tuple.

# %%
colors = ("red", "blue", "green", "yellow", "black")

# %%
colors = list(colors)

# %%
colors
# Out:
# ['red', 'blue', 'green', 'yellow', 'black']

# %%
colors[1] = 'teal green'

# %%
colors
# Out:
# ['red', 'teal green', 'green', 'yellow', 'black']

# %%
colors.append('white')

# %%
colors
# Out:
# ['red', 'teal green', 'green', 'yellow', 'black', 'white']

# %%
colors = tuple(colors)

# %%
colors
# Out:
# ('red', 'teal green', 'green', 'yellow', 'black', 'white')

# %% [markdown]
# ### 3. Set Operations:

# %% [markdown]
# #### 1)Create two sets of random numbers.

# %%
set1 = {1,2,3,4,5}

# %%
set2 = {11,22,33,44,55}

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set2
# Out:
# {11, 22, 33, 44, 55}

# %% [markdown]
# #### 2) Find and print their union, intersection, and difference.

# %%
set1 = {1,2,3,4,5}

# %%
set2 = {3,4,5,6,7}

# %%
print("union:", set1.union(set2))
# Out:
# union: {1, 2, 3, 4, 5, 6, 7}

# %%
print("intersection:",set1.intersection(set2))
# Out:
# intersection: {3, 4, 5}

# %%
print("difference:",set1.difference(set2))
# Out:
# difference: {1, 2}

# %% [markdown]
# #### 3) Remove one element| from the first set and add a new element. |

# %%
set1 = {1,2,3,4,5}

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.remove(2)

# %%
set1
# Out:
# {1, 3, 4, 5}

# %%
set1.add(8)

# %%
set1
# Out:
# {1, 3, 4, 5, 8}

# %% [markdown]
# ### 4. Dictionary Practice:

# %% [markdown]
# #### 1)Define a dictionary for a library system with book titles as keys and available copies as values.

# %%
dict = {
    "Python Basics": 5,
    "Data Science": 3,
    "Machine Learning": 2
}

# %%
print(dict)
# Out:
# {'Python Basics': 5, 'Data Science': 3, 'Machine Learning': 2}

# %% [markdown]
# #### 2) Update the count of a specific book after it is borrowed.

# %%
dict["Data Science"] = dict["Data Science"]-1

# %%
dict
# Out:
# {'Python Basics': 5, 'Data Science': 2, 'Machine Learning': 2}

# %%
dict["Python Basics"] = dict["Python Basics"]- 1
dict["Machine Learning"] = dict["Machine Learning"]- 1

# %%
dict
# Out:
# {'Python Basics': 4, 'Data Science': 2, 'Machine Learning': 1}

# %% [markdown]
# #### 3) Add a new book to the dictionary and print the updated dictionary.

# %%
dict = {
    "Python Basics": 5,
    "Data Science": 3,
    "Machine Learning": 2
}

# %%
dict["Artificial Intelligence"] = 6

# %%
dict
# Out:
# {'Artificial Intelligence': 6}

# %%
dict
# Out:
# {'Artificial Intelligence': 6}
