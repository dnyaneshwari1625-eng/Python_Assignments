# %% [markdown]
# ## Assignment-4-->Slicing

# %% [markdown]
# ### Part A: Slicing Basics (Forward & Backward) Given: l = [10, 20, 30, 40, 50, 60, 70, 80]

# %% [markdown]
# #### What is l[2:5]?

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[2:5]
# Out:
# [30, 40, 50]

# %% [markdown]
# #### What is l[:4]?

# %%
l1 = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l1[:4]
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# #### What is l[5:]?

# %%
l2 = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l2[5:]
# Out:
# [60, 70, 80]

# %% [markdown]
# #### How do you get every second element (e.g., [10, 30, 50, 70])?

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[::2]
# Out:
# [10, 30, 50, 70]

# %% [markdown]
# #### What is the output of l[::-1]?

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %% [markdown]
# #### What is l[-4:-1]?

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[-4:-1]
# Out:
# [50, 60, 70]

# %% [markdown]
# #### What does l[6:1:-2] return?

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[6:1:-2]
# Out:
# [70, 50, 30]

# %% [markdown]
# #### How would you write a slice to get the last three elements?

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[-3:]
# Out:
# [60, 70, 80]

# %% [markdown]
# ### Part B: Nested Lists. Given: nested = [1, 2, [100, 200, [300, 400]], 5]

# %% [markdown]
# #### What is the index of the sub-list [100, 200, [300, 400]]?

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2]
# Out:
# [100, 200, [300, 400]]

# %% [markdown]
# #### Access the number 200.

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2][1]
# Out:
# 200

# %% [markdown]
# #### Access the number 400.

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2][2][1]
# Out:
# 400

# %% [markdown]
# #### If you run nested[2][1] = 250, what does the list look like now?

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2][1] = 250

# %%
nested
# Out:
# [1, 2, [100, 250, [300, 400]], 5]

# %% [markdown]
# #### How do you slice the inner list to get [100, 200]?

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2][:2]
# Out:
# [100, 200]

# %% [markdown]
# ### Part C: Advanced & Mixed Concepts Given: data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# #### How do you access the entire second row [4, 5, 6]?

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
data[1]
# Out:
# [4, 5, 6]

# %% [markdown]
# #### What is data[1][1:3]?

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
data[1][1:3]
# Out:
# [5, 6]

# %% [markdown]
# #### How do you access the number 9 using negative indexing?

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
data[-1][-1]
# Out:
# 9

# %% [markdown]
# #### If x = [1, 2, 3], what is the difference between x.append([4, 5]) and x.extend([4, 5])?

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
x = [1, 2, 3]
x.append([4, 5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %% [markdown]
# x = [1, 2, 3]
# x.extend([4, 5])
# print(x)

# %%
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
x = [1, 2, 3]
x.append([4, 5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ### append() adds the entire object as one element...whereaws extend() adds each element of the iterable separately.

# %% [markdown]
# #### Given: z = [10, 20, 50, 76, 89, 56, 87, 90]. What is z[-3::-1]?

# %%
z = [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[-3::-1]
# Out:
# [56, 89, 76, 50, 20, 10]

# %% [markdown]
# #### Write code to reverse only the middle three elements of a 5-element list.

# %%
x = [1,2,3,4,5]

# %%
x[1:4]
# Out:
# [2, 3, 4]

# %%
x[1:4] = x[1:4][::-1]
print(x)
# Out:
# [1, 4, 3, 2, 5]

# %%
x
# Out:
# [1, 4, 3, 2, 5]

# %% [markdown]
# #### Create a nested list where the first element is a string, and the second element is a slice of [1, 2, 3, 4, 5].

# %%
nested = ["Hello", [1, 2, 3, 4, 5][1:4]]

# %%
nested
# Out:
# ['Hello', [2, 3, 4]]
