# %% [markdown]
# ## Assignment 3 (List & Slicing)

# %% [markdown]
# ### 1. Deep Indexing Practice

# %% [markdown]
# #### Given the list: data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"] ..Task: Write the code to extract the word "target".

# %%
data = ["a","b",["c",["d","e","target"],"f"],"g"]

# %%
print(data[2][1][2])
# Out:
# target

# %% [markdown]
# ### 2. Append vs. Extend Given: colors = ["red", "blue"]

# %% [markdown]
# #### Task A: Add the list ["green", "yellow"] so the result is ['red', 'blue', ['green', 'yellow']].

# %%
colors = ["red","blue"]

# %%
colors.append(["green", "yellow"])

# %%
colors
# Out:
# ['red', 'blue', ['green', 'yellow']]

# %% [markdown]
# #### Task B: Add the same list so the result is ['red', 'blue', 'green', 'yellow']

# %%
colors = ["red","blue"]

# %%
colors.extend(['green','yellow'])

# %%
colors
# Out:
# ['red', 'blue', 'green', 'yellow']

# %% [markdown]
# ### 3. Matrix Access Matrices are often represented as nested lists: matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# #### •	Task: Access the number 6.

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1][2]
# Out:
# 6

# %% [markdown]
# ### 4. Using .insert() Given: nums = [10, 20, 40]

# %% [markdown]
# #### Task: Insert the number 30 at the correct spot to keep the list numerical.

# %%
nums = [10, 20, 40]

# %%
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ### 5. Mixed Data Types Given: mixed = [1, "Python", [True, False]]

# %% [markdown]
# #### •	Task: Change False to None.

# %%
mixed = [1, "Python", [True, False]]

# %%
mixed[2][1] = None

# %%
mixed
# Out:
# [1, 'Python', [True, None]]

# %% [markdown]
# ### Part 1: Nested List Indexing

# %% [markdown]
# #### Example 1: Accessing Triple-Nested Items Given the list: nested = [1, [2, 3, [4, 5, 6]], 7]

# %% [markdown]
# #### task A : •	Access 2

# %%
nested = [1, [2, 3, [4, 5, 6]], 7]

# %%
nested[1][0]
# Out:
# 2

# %% [markdown]
# #### task B : Access [4, 5, 6]

# %%
nested = [1, [2, 3, [4, 5, 6]],7]

# %%
nested[1][2]
# Out:
# [4, 5, 6]

# %% [markdown]
# #### task C : •	Access 5

# %%
nested = [1, [2, 3, [4, 5, 6]],7]

# %%
nested[1][2][1]
# Out:
# 5

# %% [markdown]
# ### Example 2: Matrix-Style Access Given a 3x3 matrix: matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %% [markdown]
# #### task A : •	Access the middle row:

# %%
matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
matrix[1]
# Out:
# [40, 50, 60]

# %% [markdown]
# #### task B : •	Access the number 90

# %%
matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
matrix[2][2]
# Out:
# 90

# %% [markdown]
# #### task C :•	Access the number 40

# %%
matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
matrix[1][0]
# Out:
# 40

# %% [markdown]
# ### Part 2: List Methods (append, extend, insert)

# %% [markdown]
# #### Example 3: append() vs. extend() Let fruits = ['apple', 'banana'].

# %% [markdown]
# #### task A •	Using append():

# %%
fruits = ['apple', 'banana']

# %%
fruits.append(['kiwi','mango'])

# %%
fruits
# Out:
# ['apple', 'banana', ['kiwi', 'mango']]

# %% [markdown]
# #### task B •	Using extend():

# %%
fruits = ['apple', 'banana']

# %%
fruits.extend(['kiwi','mango'])

# %%
fruits
# Out:
# ['apple', 'banana', 'kiwi', 'mango']

# %% [markdown]
# ### Example 4: Using insert() Given nums = [10, 20, 40, 50].

# %% [markdown]
# #### •	Task: Insert 30 at the correct numerical position.

# %%
nums = [10, 20, 40, 50]

# %%
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ### Part 3: Advanced Practice Challenges

# %% [markdown]
# #### 1.	Challenge: What is the output of l[2][1] if l = [5, 6, [7, 8, 9], 10]?

# %%
l = [5, 6, [7, 8, 9], 10]

# %%
l[2][1]
# Out:
# 8

# %% [markdown]
# #### 2.	Challenge: If data = [1, 2], what does data.extend([3, [4, 5]]) produce?

# %%
 data = [1, 2]

# %%
data.extend([3, [4, 5]])

# %%
data
# Out:
# [1, 2, 3, [4, 5]]

# %% [markdown]
# #### 3.	Challenge: How do you change 'hello' to 'hi' in x = [10, [20, 'hello']]?

# %%
x = [10, [20, 'hello']]

# %%
x[1][1] = 'hi'

# %%
print(x)
# Out:
# [10, [20, 'hi']]

# %% [markdown]
# #### 4.	Challenge: Given vals = [1, 2, 3], what is the result of vals.insert(0, [0])?

# %%
vals = [1, 2, 3]

# %%
vals.insert(0, [0])

# %%
vals
# Out:
# [[0], 1, 2, 3]

# %% [markdown]
# #### 5.	Challenge: Given a = [1, 2] and b = [3, 4], what is a.append(b) followed by len(a)?

# %%
 a = [1, 2] 
 b = [3, 4]

# %%
a.append(b)

# %%
a
# Out:
# [1, 2, [3, 4]]

# %%
len(a)
# Out:
# 3
