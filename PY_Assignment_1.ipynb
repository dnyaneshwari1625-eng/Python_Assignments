# %% [markdown]
# ## Assignment 1: Python Basics and Data Types

# %% [markdown]
# ### 1. Variable Manipulation:

# %% [markdown]
# #### 1)Define variables to store a student's name, age, GPA, and list of subjects.

# %%
student_name = "Agastya Dhage"

# %%
age = 21

# %%
GPA = 7.9

# %%
subjects = ["Mathematics","Physics","English","Computer Science","DSA"]

# %%
age
# Out:
# 21

# %%
student_name
# Out:
# 'Agastya Dhage'

# %%
GPA
# Out:
# 7.9

# %%
subjects
# Out:
# ['Mathematics', 'Physics', 'English', 'Computer Science', 'DSA']

# %% [markdown]
# #### 2)Convert age from years to months and display the result.

# %%
age = 21

# %%
age_in months = age*12
# Out:
#   Cell In[13], line 1
#     age_in months = age*12
#            ^
# SyntaxError: invalid syntax

# %%
age_in_months = age*12

# %%
age_in_months
# Out:
# 252

# %% [markdown]
# #### 3)Concatenate and print a sentence using all the defined variables.

# %%
name = "Agastya Dhage"

# %%
age = 21

# %%
education = " pursuing B.Tech in Computer Science"

# %%
GPA = 7.9

# %%
print(name + " is " + str(age) + " years old,has a GPA of " + str(GPA) + " and " + education + ".")
# Out:
# Agastya Dhage is 21 years old,has a GPA of 7.9 and  pursuing B.Tech in Computer Science.

# %% [markdown]
# ### 2. Type Conversion Practice:

# %% [markdown]
# #### 1) Convert a float to an integer, and explain what happens to the decimal part.

# %%
num = 7.9

# %%
integer = int(num)

# %%
print(integer)
# Out:
# 7

# %%
type(num)
# Out:
# float

# %%
type(integer)
# Out:
# int

# %% [markdown]
# ##### When we use int() on a float, Python removes the decimal part. It does not round the number.
